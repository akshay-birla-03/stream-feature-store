# %% [markdown]
# # Stream Feature Store — one-click run
#
# This notebook clones the repository, installs it, and runs the demo end-to-end. **Runtime → Run all**.
#
# Runs fully on the free Colab CPU runtime — no API keys, no data downloads (all demo data is generated in code).

# %% [markdown]
# ### 1. Clone the repository

# %%
import os
if not os.path.isdir('/content/stream-feature-store'):
    # !git clone -q https://github.com/akshay-birla-03/stream-feature-store.git /content/stream-feature-store
# %cd /content/stream-feature-store

# %% [markdown]
# ### 2. Install

# %%
# !pip install -q -e .

# %% [markdown]
# ### 3. Run the demo

# %%
# !featurestore --n-users 5 --n-events 300 --n-labels 20
